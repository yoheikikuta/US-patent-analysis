# %% [markdown]
# `Patent Grant Full Text Data/XML Version 4.2 ICE (JAN 2012 - DEC 2012)`

# %%
import os

TARGET_FILES = """
ipg120103.zip
ipg120110.zip
ipg120117.zip
ipg120124.zip
ipg120131.zip
ipg120207.zip
ipg120214.zip
ipg120221.zip
ipg120228.zip
ipg120306.zip
ipg120313.zip
ipg120320.zip
ipg120327.zip
ipg120403.zip
ipg120410.zip
ipg120417.zip
ipg120424.zip
ipg120501.zip
ipg120508.zip
ipg120515.zip
ipg120522.zip
ipg120529.zip
ipg120605.zip
ipg120612.zip
ipg120619.zip
ipg120626.zip
ipg120703.zip
ipg120710.zip
ipg120717.zip
ipg120724.zip
ipg120731.zip
ipg120807.zip
ipg120814.zip
ipg120821.zip
ipg120828.zip
ipg120904.zip
ipg120911.zip
ipg120918.zip
ipg120925.zip
ipg121002.zip
ipg121009.zip
ipg121016.zip
ipg121023.zip
ipg121030.zip
ipg121106.zip
ipg121113.zip
ipg121120.zip
ipg121127.zip
ipg121204.zip
ipg121211.zip
ipg121218.zip
ipg121225.zip"""

# %%
TARGET_LIST = TARGET_FILES.split("\n")[1:]

URL = "https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2012/"
DATADIR = "../data/grants2012/"

os.makedirs(DATADIR, exist_ok=True)

for file in TARGET_LIST:
    # !wget {URL}{file} -P {DATADIR}
    # !unzip {DATADIR}{file} -d {DATADIR}
    # !rm {DATADIR}{file}
# Out:
# --2018-08-29 23:44:04--  https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2012/ipg120124.zip
# Resolving bulkdata.uspto.gov... 2610:20:5004:1604::28, 151.207.240.28
# Connecting to bulkdata.uspto.gov|2610:20:5004:1604::28|:443... failed: Connection refused.
# Connecting to bulkdata.uspto.gov|151.207.240.28|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79453738 (76M) [application/zip]
# Saving to: '../data/grants2012/ipg120124.zip'
#
# ipg120124.zip       100%[===================>]  75.77M   369KB/s    in 3m 38s
#
# 2018-08-29 23:48:09 (356 KB/s) - '../data/grants2012/ipg120124.zip' saved [79453738/79453738]
#
# Archive:  ../data/grants2012/ipg120124.zip
#   inflating: ../data/grants2012/ipg120124.xml
# --2018-08-29 23:48:12--  https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2012/ipg120131.zip
# Resolving bulkdata.uspto.gov... 2610:20:5004:1604::28, 151.207.240.28
# ...

# %% [markdown]
# `https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2017/`

# %%
import os

TARGET_FILES = """
ipa170105.zip
ipa170112.zip
ipa170119.zip
ipa170126.zip
ipa170202.zip
ipa170209.zip
ipa170216.zip
ipa170223.zip
ipa170302.zip
ipa170309.zip
ipa170316.zip
ipa170323.zip
ipa170330.zip
ipa170406.zip
ipa170413.zip
ipa170420.zip
ipa170427.zip
ipa170504.zip
ipa170511.zip
ipa170518.zip
ipa170525.zip
ipa170601.zip
ipa170608.zip
ipa170615.zip
ipa170622.zip
ipa170629.zip
ipa170706.zip
ipa170713.zip
ipa170720.zip
ipa170727.zip
ipa170803.zip
ipa170810.zip
ipa170817.zip
ipa170824.zip
ipa170831.zip
ipa170907.zip
ipa170914.zip
ipa170921.zip
ipa170928.zip
ipa171005.zip
ipa171012.zip
ipa171019.zip
ipa171026.zip
ipa171102.zip
ipa171109.zip
ipa171116.zip
ipa171123.zip
ipa171130.zip
ipa171207.zip
ipa171214.zip
ipa171221.zip
ipa171228.zip
"""

# %%
TARGET_LIST = TARGET_FILES.split("\n")[1:]

URL = "https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2017/"
DATADIR = "../data/application2017/"

os.makedirs(DATADIR, exist_ok=True)

for file in TARGET_LIST:
    # !wget {URL}{file} -P {DATADIR}
    # !unzip {DATADIR}{file} -d {DATADIR}
    # !rm {DATADIR}{file}
# Out:
# --2018-08-30 03:25:27--  https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2017/ipa170105.zip
# Resolving bulkdata.uspto.gov... 2610:20:5004:1604::28, 151.207.240.28
# Connecting to bulkdata.uspto.gov|2610:20:5004:1604::28|:443... failed: Connection refused.
# Connecting to bulkdata.uspto.gov|151.207.240.28|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 129958778 (124M) [application/zip]
# Saving to: '../data/application2017/ipa170105.zip'
#
# ipa170105.zip       100%[===================>] 123.94M   363KB/s    in 5m 53s
#
# 2018-08-30 03:31:38 (359 KB/s) - '../data/application2017/ipa170105.zip' saved [129958778/129958778]
#
# Archive:  ../data/application2017/ipa170105.zip
#   inflating: ../data/application2017/ipa170105.xml
# --2018-08-30 03:31:42--  https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2017/ipa170112.zip
# Resolving bulkdata.uspto.gov... 2610:20:5004:1604::28, 151.207.240.28
# ...
